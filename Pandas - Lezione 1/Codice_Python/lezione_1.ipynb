# %%
# pip install pandas

# %%
# Importa la libreria pandas (pd)
import pandas as pd

# %%
# Legge il file 'data.csv' caricato in 'sample_data' e lo salva in df (DataFrame); df è un dataset
df = pd.read_csv('sample_data/data.csv')

# %%
# Mostra le prime cinque righe del dataset
df.head()
# Out:
#    durata  pulsazione  pulsazione_max  calorie
# 0      60         110           130.0    409.1
# 1      60         117           145.0    479.0
# 2      60         103             NaN    340.0
# 3      45         109           175.0    282.4
# 4      45         117           148.0    406.0

# %%
# Mostra le prime dieci righe del dataset
df.head(10)
# Out:
#    durata  pulsazione  pulsazione_max  calorie
# 0      60         110           130.0    409.1
# 1      60         117           145.0    479.0
# 2      60         103             NaN    340.0
# 3      45         109           175.0    282.4
# 4      45         117           148.0    406.0
# 5      60         102           127.0    300.0
# 6      60         110           136.0    374.0
# 7      45         104           134.0    253.3
# 8      30         109           133.0    195.1
# 9      60          98           124.0    269.0

# %%
# Mostra le ultime cinque righe del dataset
df.tail()
# Out:
#      durata  pulsazione  pulsazione_max  calorie
# 164      60         105           140.0    290.8
# 165      60         110           145.0    300.0
# 166      60         115           145.0    310.2
# 167      75         120           150.0    320.4
# 168      75         125           150.0    330.4

# %%
# Mostra il numero di righe, colonne, la tipologia dei dati e il numero di dati mancanti nel dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   durata          169 non-null    int64
#  1   pulsazione      169 non-null    int64
#  2   pulsazione_max  168 non-null    float64
#  3   calorie         164 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.4 KB
